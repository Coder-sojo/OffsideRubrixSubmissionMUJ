# %% [markdown]
# # OffSide 2026 - Football Analytics Challenge
#
# Predict the probability that a player scores at least one goal in a match.

# %% [markdown]
# ## How to run
#
# This notebook uses the production script so the notebook and final submission stay reproducible. Ensure `data/train.csv` and `data/test.csv` exist, then run the cells below.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
PROJECT_ROOT

# %% [markdown]
# ## Train model and create submission
#
# Use `--fast` for a quick smoke test. Remove it for the final leaderboard run.

# %%
# !python3 src/train_model.py --fast

# %% [markdown]
# ## Validate submission

# %%
# !python3 src/validate_submission.py outputs/solution.csv data/test.csv

# %% [markdown]
# ## EDA insights to report
#
# After the script runs, inspect `outputs/metrics.json` and the plots in `outputs/eda_plots/`. Add final leaderboard/CV numbers here before presenting.
#
# Key expected insights:
# - Scoring is imbalanced, so Average Precision is more informative than accuracy.
# - Attacking roles and xG/shot-volume metrics should be highly predictive.
# - Minutes played and starter/full-match context affect scoring opportunity.
